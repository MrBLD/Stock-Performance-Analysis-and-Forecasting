# %% [markdown]
# #### Data Science

# %% [markdown]
# Importing data in panda
#
#
# fix data
#
#
#         -set symbol to INFY+'-'+Series
#
#         -remove series
#
#         -find average of all half years
#
#         -examine NaN and fix it
#
# Visualisation

# %%
import pandas as pd
import numpy as np
# import matplotlib as mpl
# import matplotlib.pyplot as plt
import re
INFYdf=pd.read_csv('INFY.csv')
print("Data imported")
INFYdf
# Out:
# Data imported
#             Date      Symbol Series  Prev Close      Open      High       Low  \
# 0     2000-01-03  INFOSYSTCH     EQ    14467.75  15625.00  15625.20  15625.00
# 1     2000-01-04  INFOSYSTCH     EQ    15625.20  16800.00  16875.25  16253.00
# 2     2000-01-05  INFOSYSTCH     EQ    16855.90  15701.00  16250.00  15507.45
# 3     2000-01-06  INFOSYSTCH     EQ    15507.45  15256.65  15300.00  14266.85
# 4     2000-01-07  INFOSYSTCH     EQ    14266.85  13125.50  13125.50  13125.50
# ...          ...         ...    ...         ...       ...       ...       ...
# 5301  2021-04-26        INFY     EQ     1333.80   1332.25   1351.30   1321.00
# 5302  2021-04-27        INFY     EQ     1343.55   1346.00   1353.00   1340.15
# 5303  2021-04-28        INFY     EQ     1348.50   1358.00   1359.50   1344.60
# 5304  2021-04-29        INFY     EQ     1356.00   1368.00   1369.00   1351.40
# 5305  2021-04-30        INFY     EQ     1356.35   1346.30   1373.90   1345.90
#
# ...

# %%
print(INFYdf.columns)
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
INFYdf['Symbol'] = 'INFY-' + INFYdf['Series']
INFYdf.drop('Series', axis=1, inplace=True)
INFYdf

# INFYdf.isna().sum()
# INFYdf.fillna(INFYdf.mean(), inplace=True)
# Out:
#             Date   Symbol  Prev Close      Open      High       Low      Last  \
# 0     2000-01-03  INFY-EQ    14467.75  15625.00  15625.20  15625.00  15625.20
# 1     2000-01-04  INFY-EQ    15625.20  16800.00  16875.25  16253.00  16875.25
# 2     2000-01-05  INFY-EQ    16855.90  15701.00  16250.00  15507.45  15507.45
# 3     2000-01-06  INFY-EQ    15507.45  15256.65  15300.00  14266.85  14266.85
# 4     2000-01-07  INFY-EQ    14266.85  13125.50  13125.50  13125.50  13125.50
# ...          ...      ...         ...       ...       ...       ...       ...
# 5301  2021-04-26  INFY-EQ     1333.80   1332.25   1351.30   1321.00   1345.00
# 5302  2021-04-27  INFY-EQ     1343.55   1346.00   1353.00   1340.15   1347.50
# 5303  2021-04-28  INFY-EQ     1348.50   1358.00   1359.50   1344.60   1355.80
# 5304  2021-04-29  INFY-EQ     1356.00   1368.00   1369.00   1351.40   1356.00
# 5305  2021-04-30  INFY-EQ     1356.35   1346.30   1373.90   1345.90   1348.60
#
# ...

# %%
INFYdf['Date'] = pd.to_datetime(INFYdf['Date'])
INFYdf['half_year'] = INFYdf['Date'].dt.year.astype(str) + '-' + ((INFYdf['Date'].dt.month-1)//6 + 1).astype(str)
INFYdf.groupby('half_year').mean()
# INFYdf
# Out:
# C:\Users\bhask\AppData\Local\Temp\ipykernel_9984\61700857.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   INFYdf.groupby('half_year').mean()
#             Prev Close         Open         High          Low         Last  \
# half_year
# 2000-1     9297.043548  9280.081452  9583.609274  8932.296371  9243.237097
# 2000-2     7462.186111  7460.341667  7603.929762  7301.347222  7444.601587
# 2001-1     4766.869600  4766.485200  4886.624800  4616.370800  4749.563200
# 2001-2     3402.759350  3399.408537  3487.860976  3313.252439  3407.211789
# 2002-1     3763.587698  3772.546429  3836.448810  3695.958333  3755.093651
# 2002-2     3739.113200  3739.970400  3796.016800  3697.415600  3751.966000
# 2003-1     3713.304435  3712.912097  3769.458871  3641.053629  3702.319355
# ...

# %%
# plt.plot(INFYdf['Date'], INFYdf['Close'])
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.title('Line graph of Close over time')
# plt.show()
